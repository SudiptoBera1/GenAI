# %% [markdown]
# # LangChain: Connecting with Multiple LLMs (Simple Demo)
#
# This notebook shows how **LangChain helps an application work with
# different Large Language Models (LLMs)** without changing the entire code.
#
# Instead of talking directly to OpenAI or Gemini,
# the application talks to **LangChain**.
#
# LangChain then connects to the selected LLM behind the scenes.

# %% [markdown]
# ## What is the goal of this notebook?
#
# The goal is to show a simple idea:
#
# Application → LangChain → Different LLMs
#
# In this demo, LangChain is used with:
# - OpenAI (gpt-4o-mini)
# - Google Gemini (gemini-2.5-flash-lite)
#
# This makes it easier to switch models, avoid vendor lock-in,
# and experiment with different LLMs.

# %% [markdown]
# ## Loading environment variables
#
# API keys are stored as environment variables
# to keep sensitive information out of the code.

# %%
### langchain - Model - OpenAi
### dienv

# %% [markdown]
# Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Connect with Google Gemini model

# %% [markdown]
# ## Using LangChain with Google Gemini
#
# Here, LangChain is connected to the Google Gemini model.
#
# The application does not directly depend on Gemini.
# LangChain handles the connection.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = model.invoke('What is GenAI ? Expain  me in pontrs')

# %%
res.content
# Out:
# 'Here\'s a breakdown of GenAI in points:\n\n**What is GenAI?**\n\n*   **Generative Artificial Intelligence (GenAI)** is a type of AI that can **create new, original content**.\n*   Unlike traditional AI that analyzes or classifies existing data, GenAI **produces entirely new outputs**.\n*   This content can take many forms, including:\n    *   **Text:** Stories, poems, articles, code, emails, scripts, summaries.\n    *   **Images:** Realistic photos, artistic illustrations, logos, concept art.\n    *   **Audio:** Music, voiceovers, sound effects.\n    *   **Video:** Short clips, animations, synthetic footage.\n    *   **Code:** Software programs, scripts, website layouts.\n    *   **3D Models:** Objects, environments, characters.\n\n**How does it work (in simple terms)?**\n\n*   **Learns from vast amounts of data:** GenAI models are trained on massive datasets of existing content (text, images, audio, etc.).\n*   **Identifies patterns and relationships:** Through this training, they learn the underlying structure, style, and characteristics of the data.\n*   **Generates new content based on prompts:** When given a prompt (a request or instruction), the AI uses its learned patterns to predict and assemble new content that is statistically likely to fit the prompt.\n\n**Key Characteristics and Concepts:**\n\n*   **Prompt Engineering:** The art and science of crafting effective prompts to guide the AI to produce desired outputs.\n*   **Models:** GenAI relies on sophisticated machine learning models, often based on **Large Language Models (LLMs)** for text generation and **Diffusion Models** or **Generative Adversarial Networks (GANs)** for image generation.\n*   **Creativity and Novelty:** While based on learned patterns, GenAI can produce outputs that are often perceived as creative and novel, going beyond simple repetition.\n*   **Probabilistic Nature:** GenAI\'s outputs are probabilistic. It\'s generating the "most likely" next piece of content based on its training. This means outputs can vary even with the same prompt.\n\n**Applications and Use Cases:**\n\n*   **Content Creation:** Writing marketing copy, drafting emails, generating social media posts, creating blog articles.\n*   **Art and Design:** Generating illustrations, concept art, product designs, visual effects.\n*   **Software Development:** Writing code snippets, debugging, generating boilerplate code, assisting with documentation.\n*   **Education:** Creating learning materials, personalized quizzes, summarizing complex topics.\n*   **Entertainment:** Generating scripts for movies and games, composing music, creating virtual characters.\n*   **Research and Development:** Simulating experiments, discovering new materials, generating hypotheses.\n\n**Important Considerations:**\n\n*   **Accuracy and Factual Correctness:** GenAI can sometimes produce inaccurate or fabricated information ("hallucinations"). Human oversight and fact-checking are crucial.\n*   **Bias:** The training data can contain biases, which can be reflected in the generated content.\n*   **Ethical Implications:** Concerns around copyright, plagiarism, misinformation, job displacement, and responsible use are significant.\n*   **Evolving Technology:** GenAI is a rapidly developing field with new capabilities and models emerging constantly.'

# %%
print(res.content)
# Out:
# Here's a breakdown of GenAI in points:
#
# **What is GenAI?**
#
# *   **Generative Artificial Intelligence (GenAI)** is a type of AI that can **create new, original content**.
# *   Unlike traditional AI that analyzes or classifies existing data, GenAI **produces entirely new outputs**.
# *   This content can take many forms, including:
#     *   **Text:** Stories, poems, articles, code, emails, scripts, summaries.
#     *   **Images:** Realistic photos, artistic illustrations, logos, concept art.
#     *   **Audio:** Music, voiceovers, sound effects.
#     *   **Video:** Short clips, animations, synthetic footage.
#     *   **Code:** Software programs, scripts, website layouts.
#     *   **3D Models:** Objects, environments, characters.
#
# **How does it work (in simple terms)?**
#
# *   **Learns from vast amounts of data:** GenAI models are trained on massive datasets of existing content (text, images, audio, etc.).
# *   **Identifies patterns and relationships:** Through this training, they learn the underlying structure, style, and characteristics of the data.
# *   **Generates new content based on prompts:** When given a prompt (a request or instruction), the AI uses its learned patterns to predict and assemble new content that is statistically likely to fit the prompt.
#
# **Key Characteristics and Concepts:**
#
# *   **Prompt Engineering:** The art and science of crafting effective prompts to guide the AI to produce desired outputs.
# *   **Models:** GenAI relies on sophisticated machine learning models, often based on **Large Language Models (LLMs)** for text generation and **Diffusion Models** or **Generative Adversarial Networks (GANs)** for image generation.
# *   **Creativity and Novelty:** While based on learned patterns, GenAI can produce outputs that are often perceived as creative and novel, going beyond simple repetition.
# *   **Probabilistic Nature:** GenAI's outputs are probabilistic. It's generating the "most likely" next piece of content based on its training. This means outputs can vary even with the same prompt.
#
# **Applications and Use Cases:**
#
# *   **Content Creation:** Writing marketing copy, drafting emails, generating social media posts, creating blog articles.
# *   **Art and Design:** Generating illustrations, concept art, product designs, visual effects.
# *   **Software Development:** Writing code snippets, debugging, generating boilerplate code, assisting with documentation.
# *   **Education:** Creating learning materials, personalized quizzes, summarizing complex topics.
# *   **Entertainment:** Generating scripts for movies and games, composing music, creating virtual characters.
# *   **Research and Development:** Simulating experiments, discovering new materials, generating hypotheses.
#
# **Important Considerations:**
#
# *   **Accuracy and Factual Correctness:** GenAI can sometimes produce inaccurate or fabricated information ("hallucinations"). Human oversight and fact-checking are crucial.
# *   **Bias:** The training data can contain biases, which can be reflected in the generated content.
# *   **Ethical Implications:** Concerns around copyright, plagiarism, misinformation, job displacement, and responsible use are significant.
# *   **Evolving Technology:** GenAI is a rapidly developing field with new capabilities and models emerging constantly.

# %% [markdown]
# # Connect with OpenAi Model

# %% [markdown]
# ## Using LangChain with OpenAI
#
# In this section, LangChain is connected to an OpenAI model.
#
# Notice how the application structure stays the same.
# Only the model configuration changes.

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model = "gpt-4o-mini")

# %%
res = llm.invoke("How to find largest no in a list using python")

# %%
res.content
# Out:
# 'You can find the largest number in a list in Python using the built-in `max()` function, which is the simplest and most efficient way to do this. Here\'s how you can do it:\n\n```python\n# Example list\nnumbers = [10, 5, 23, 42, 16, 7]\n\n# Finding the largest number\nlargest_number = max(numbers)\n\nprint("The largest number in the list is:", largest_number)\n```\n\nAlternatively, if you\'d like to find the largest number without using the built-in `max()` function, you can do so by manually iterating through the list. Here\'s an example:\n\n```python\n# Example list\nnumbers = [10, 5, 23, 42, 16, 7]\n\n# Initialize the largest number with the first element of the list\nlargest_number = numbers[0]\n\n# Iterate through the list\nfor number in numbers:\n    if number > largest_number:\n        largest_number = number\n\nprint("The largest number in the list is:", largest_number)\n```\n\nBoth methods will give you the largest number in the provided list. Using `max()` is more concise and generally preferred for clarity and simplicity.'

# %%
print(res.content)
# Out:
# You can find the largest number in a list in Python using the built-in `max()` function, which is the simplest and most efficient way to do this. Here's how you can do it:
#
# ```python
# # Example list
# numbers = [10, 5, 23, 42, 16, 7]
#
# # Finding the largest number
# largest_number = max(numbers)
#
# print("The largest number in the list is:", largest_number)
# ```
#
# Alternatively, if you'd like to find the largest number without using the built-in `max()` function, you can do so by manually iterating through the list. Here's an example:
#
# ```python
# # Example list
# numbers = [10, 5, 23, 42, 16, 7]
#
# # Initialize the largest number with the first element of the list
# largest_number = numbers[0]
#
# # Iterate through the list
# for number in numbers:
#     if number > largest_number:
#         largest_number = number
#
# print("The largest number in the list is:", largest_number)
# ```
#
# Both methods will give you the largest number in the provided list. Using `max()` is more concise and generally preferred for clarity and simplicity.

# %% [markdown]
# # Static Prompts

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
prompts = [
    ("system" , "You are a python developer"), ### (type,) "system" ,"ai","user"
    ("user", "How to sort an array")
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Sorting an array in Python can be done using various methods. The most common ways to sort an array (or list) are by using the built-in `sort()` method for lists, or the `sorted()` function. Below are examples of both methods:
#
# ### Using the `sort()` Method
#
# The `sort()` method sorts a list in place and modifies the original list. It does not return a new list.
#
# ```python
# # Example of using sort()
# my_list = [5, 2, 9, 1, 5, 6]
# my_list.sort()  # Sorts the list in-place
# print(my_list)  # Output: [1, 2, 5, 5, 6, 9]
# ```
#
# ### Using the `sorted()` Function
#
# The `sorted()` function returns a new list that is sorted, leaving the original list unchanged.
#
# ```python
# # Example of using sorted()
# my_list = [5, 2, 9, 1, 5, 6]
# sorted_list = sorted(my_list)  # Returns a new sorted list
# print(sorted_list)  # Output: [1, 2, 5, 5, 6, 9]
# print(my_list)      # Output: [5, 2, 9, 1, 5, 6] (original list remains unchanged)
# ```
#
# ### Sorting in Reverse Order
#
# Both the `sort()` method and the `sorted()` function can sort in reverse order by using the `reverse` parameter.
#
# ```python
# # Using sort() to sort in reverse
# my_list = [5, 2, 9, 1, 5, 6]
# my_list.sort(reverse=True)  # Sorts in-place in descending order
# print(my_list)  # Output: [9, 6, 5, 5, 2, 1]
#
# # Using sorted() to sort in reverse
# my_list = [5, 2, 9, 1, 5, 6]
# sorted_list = sorted(my_list, reverse=True)  # Returns a new sorted list
# print(sorted_list)  # Output: [9, 6, 5, 5, 2, 1]
# print(my_list)      # Output: [5, 2, 9, 1, 5, 6] (original list remains unchanged)
# ```
#
# ### Custom Sorting
#
# You can also sort a list based on a custom criterion using the `key` parameter. For example, you might want to sort a list of strings by their lengths:
#
# ```python
# # Sorting by length of strings
# words = ["apple", "banana", "fig", "cherry", "date"]
# sorted_words = sorted(words, key=len)  # Sorts by string length
# print(sorted_words)  # Output: ['fig', 'date', 'apple', 'banana', 'cherry']
# ```
#
# These methods provide flexibility in sorting arrays or lists in Python, depending on your specific needs.

# %% [markdown]
# ## Key takeaway
#
# LangChain acts as a middle layer between an application
# and different LLM providers.
#
# Different models.
# Same framework.
# Cleaner design.
